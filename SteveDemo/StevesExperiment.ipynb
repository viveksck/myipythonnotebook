# %%
import numpy
import pandas as pd
import pylab as pl
from os import path

# %%
def get_changed_words(df, means, errs, year, deviations=1):
  changedf = df[df[year] > (means[year] + deviations * errs[year])]
  changedf = changedf.sort([year], ascending=False)
  return changedf

def get_stable_words(df, means, errs, year, deviations=1):
  stabledf = df[df[year] < (means[year] - deviations * errs[year])]
  stabledf = stabledf.sort([year])
  return stabledf

# %%
def get_num_ngrams(w, year, prefix='eng-fiction'):
  input_file = path.join('../mit_lm/topngrams/' + prefix + '/' + year, w + '.txt')
  with open(input_file) as foo:
    lines = foo.readlines()
    if lines:
      return len(lines), lines[0].strip()
    else:
      return 0, None

# %%
def create_changed_dataframe(csrc, filter_ngrams=False):
    filteredwords=[]
    new_words = []
    for w in csrc.word:
        num_ngrams_src, ngram_src = get_num_ngrams(w, str(csrc.columns[2])) 
        num_ngrams_dest, ngram_dest = get_num_ngrams(w, str(csrc.columns[-1]))
        if num_ngrams_src  == 0:
          new_words.append([w])
        if  filter_ngrams and num_ngrams_src> 40:
          filteredwords.append([w, ngram_src, ngram_dest])
        if  filter_ngrams == False and num_ngrams_src > 0:
          filteredwords.append([w, ngram_src, ngram_dest])
        header = ['word', 'past', 'now']
    cdf = pd.DataFrame.from_records(filteredwords, columns=header)
    newwords_df = pd.DataFrame.from_records(new_words, columns=['word'])
    return cdf, newwords_df

# %%
def get_rows_to_index(df, words):
  rows_to_index=[]
  for w in words:
    if w in df.word.values:
      rows_to_index.append(df[df.word == w].index[0])
  return rows_to_index

# %%
def load_timeseries(source_timeseries, dest_timeseries):
  sourcedf = pd.read_csv(source_timeseries)
  destdf = pd.read_csv(dest_timeseries)
  return sourcedf, destdf

# %%
def errorfill(x, y, yerr, color=None, alpha_fill=0.3, ax=None, label = ''):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        color = ax._get_lines.color_cycle.next()
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr
    ax.plot(x, y, color=color, label=label)
    ax.fill_between(x, ymax, ymin, color=color, alpha=alpha_fill)

# %%
def savitzky_golay(y, window_size, order, deriv=0, rate=1):
    r"""Smooth (and optionally differentiate) data with a Savitzky-Golay filter.
    The Savitzky-Golay filter removes high frequency noise from data.
    It has the advantage of preserving the original shape and
    features of the signal better than other types of filtering
    approaches, such as moving averages techniques.
    Parameters
    ----------
    y : array_like, shape (N,)
        the values of the time history of the signal.
    window_size : int
        the length of the window. Must be an odd integer number.
    order : int
        the order of the polynomial used in the filtering.
        Must be less then `window_size` - 1.
    deriv: int
        the order of the derivative to compute (default = 0 means only smoothing)
    Returns
    -------
    ys : ndarray, shape (N)
        the smoothed signal (or it's n-th derivative).
    Notes
    -----
    The Savitzky-Golay is a type of low-pass filter, particularly
    suited for smoothing noisy data. The main idea behind this
    approach is to make for each point a least-square fit with a
    polynomial of high order over a odd-sized window centered at
    the point.
    Examples
    --------
    t = np.linspace(-4, 4, 500)
    y = np.exp( -t**2 ) + np.random.normal(0, 0.05, t.shape)
    ysg = savitzky_golay(y, window_size=31, order=4)
    import matplotlib.pyplot as plt
    plt.plot(t, y, label='Noisy signal')
    plt.plot(t, np.exp(-t**2), 'k', lw=1.5, label='Original signal')
    plt.plot(t, ysg, 'r', label='Filtered signal')
    plt.legend()
    plt.show()
    References
    ----------
    .. [1] A. Savitzky, M. J. E. Golay, Smoothing and Differentiation of
       Data by Simplified Least Squares Procedures. Analytical
       Chemistry, 1964, 36 (8), pp 1627-1639.
    .. [2] Numerical Recipes 3rd Edition: The Art of Scientific Computing
       W.H. Press, S.A. Teukolsky, W.T. Vetterling, B.P. Flannery
       Cambridge University Press ISBN-13: 9780521880688
    """
    import numpy as np
    from math import factorial

    try:
        window_size = np.abs(np.int(window_size))
        order = np.abs(np.int(order))
    except ValueError, msg:
        raise ValueError("window_size and order have to be of type int")
    if window_size % 2 != 1 or window_size < 1:
        raise TypeError("window_size size must be a positive odd number")
    if window_size < order + 2:
        raise TypeError("window_size is too small for the polynomials order")
    order_range = range(order+1)
    half_window = (window_size -1) // 2
    # precompute coefficients
    b = np.mat([[k**i for i in order_range] for k in range(-half_window, half_window+1)])
    m = np.linalg.pinv(b).A[deriv] * rate**deriv * factorial(deriv)
    # pad the signal at the extremes with
    # values taken from the signal itself
    firstvals = y[0] - np.abs( y[1:half_window+1][::-1] - y[0] )
    lastvals = y[-1] + np.abs(y[-half_window-1:-1][::-1] - y[-1])
    y = np.concatenate((firstvals, y, lastvals))
    return np.convolve( m[::-1], y, mode='valid')

# %%
def PlotChangePointNew(dfsrc, dfdest, word, use_savitzky_golay=False, ax=None, ylim=(0,1), plot_raw=True, marker='.', win_size=5):
    if ax == None:
      fig = plt.figure()
      ax = fig.add_subplot(111)
    srcx = [int(col) for col in dfsrc.columns[2:]]
    destx = [int(col) for col in dfdest.columns[2:]]
    src_series = dfsrc[dfsrc.word == word].values[0][2:]
    dest_series = dfdest[dfdest.word == word].values[0][2:]
    if use_savitzky_golay:
      src_series_smooth = savitzky_golay(src_series,  win_size, 1)
      dest_series_smooth = savitzky_golay(dest_series[::-1],  win_size,1)
      dest_series_smooth = dest_series_smooth[::-1]
    if plot_raw:
      ax.plot(srcx, src_series, marker, label=word + 'left', c='b')
      ax.plot(destx, dest_series, marker, label=word + 'right', c='r')
    if use_savitzky_golay:
      ax.plot(srcx, src_series_smooth, label=word + 'left', c='b')
      ax.plot(destx, dest_series_smooth, label=word + 'right', c='r')
    ax.set_xlabel('Year')
    ax.set_ylabel('Distance')
    ax.set_ylim(ylim)
    ax.legend(loc ='best')

# %%
def  PlotChangePointsWords(words, sourcedf, destdf, use_savitzky_golay=False, marker='-', plot_raw=True, win_size=5):
  for w in words:
    PlotChangePointNew(sourcedf, destdf, w, use_savitzky_golay, ax=None, marker=marker, plot_raw= plot_raw, win_size=win_size)

# %%
def PlotMeanAndErrorBar(dfsrc, dfdest, use_savitzky_golay=False, ax=None, ylim=(0,1)):
  if  ax == None:
    fig = plt.figure()
    ax = fig.add_subplot(111)
  x = [int(col) for col in dfsrc.columns[2:]]
  sourcemeans = sourcedf.mean()
  sourceerrs = sourcedf.std()
  destmeans = destdf.mean()
  desterrs = destdf.std()
  errorfill(x, sourcemeans[1:], sourceerrs[1:], ax=ax, label='1900_mean')
  errorfill(x, destmeans[1:], desterrs[1:], color='y', ax=ax, label = '2005_mean')
  ax.set_xlabel('Year')
  ax.set_ylabel('Distance')
  ax.legend()
  ax.set_ylim(ylim)

# %%
def DetectChangePoint(row, dfsrc, dfdst, win_size=-1):
  src_series = dfsrc[dfsrc.word == row.word].values[0][2:]
  dest_series = dfdst[dfdst.word == row.word].values[0][2:]
  if win_size != -1:
    src_series_smooth = savitzky_golay(src_series,  win_size, 1)
    dest_series_smooth = savitzky_golay(dest_series[::-1],  win_size,1)
    dest_series_smooth = dest_series_smooth[::-1]
    points = np.where(src_series_smooth > dest_series_smooth)[0]
  else:
    points = np.where(src_series  > dest_series)[0]
  point = points[0] + 2
  return dfsrc.columns[point]

# %% [markdown]
# ## Load the data

# %%
srcfile = '../skipgram/eng-fiction/output/5000words/timeseries_5000words_1000_source.csv'
destfile = '../skipgram/eng-fiction/output/5000words/timeseries_5000words_1000_dest.csv'
sourcedf, destdf = load_timeseries(srcfile, destfile)
sourcemeans = sourcedf.mean()
sourceerrs = sourcedf.std()
destmeans = destdf.mean()
desterrs = destdf.std()

# %% [markdown]
# ## Error and mean bar

# %%
PlotMeanAndErrorBar(sourcedf, destdf, False)

# %% [markdown]
# ## Top 25 words that changed and the top 25 words which are stable

# %%
csrc = get_changed_words(sourcedf, sourcemeans, sourceerrs, sourcedf.columns[-1], deviations=1)

# %%
filter_ngrams = False
changeddf, newwdf = create_changed_dataframe(csrc, filter_ngrams=filter_ngrams)

# %%
csrc.ix[get_rows_to_index(csrc, changeddf.word.values)][:20]

# %%
changeddf[:50]

# %%
stable_src = get_stable_words(sourcedf, sourcemeans, sourceerrs, sourcedf.columns[-1], deviations=1)
stable_src[:20]

# %%
if filter_ngrams:
  file_suffix = 'Filter'
else:
  file_suffix=''
changeddf.to_csv('5000wordsChanged' + file_suffix + '.csv')
stable_src.to_csv('5000wordsStable'  + file_suffix + '.csv')

# %%
changepointdf = changeddf.copy(deep=True)
changepointdf['changepoint'] = changepointdf.apply(DetectChangePoint, axis=1, args = [sourcedf, destdf, 3])
#changepointdf = changepointdf.sort(['changepoint'], ascending=False)
changepointdf.to_csv('5000wordsWithChangePoints' + file_suffix + '.csv')

# %%
changepointdf

# %% [markdown]
# ## Time series when compared with when compared with t - k and t + k

# %%
srcfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win1_src.csv'
destfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win1_dest.csv'
sourcedf, destdf = load_timeseries(srcfile, destfile)

# %% [markdown]
# Blue line shows: t compared to t - 1
# Red line shows:  t compared to t + 1

# %%
words = sourcedf.word.values
PlotChangePointsWords(words, sourcedf, destdf, use_savitzky_golay=False, marker='-')

# %% [markdown]
# Blue line shows: t compared to t - 2
# Red line shows:  t compared to t + 2

# %%
srcfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win2_src.csv'
destfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win2_dest.csv'
sourcedf, destdf = load_timeseries(srcfile, destfile)

# %%
words = sourcedf.word.values
PlotChangePointsWords(words, sourcedf, destdf, use_savitzky_golay=False, marker='-')

# %% [markdown]
# Blue line shows: t compared to t - 3
# Red line shows:  t compared to t + 3

# %%
srcfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win3_src.csv'
destfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win3_dest.csv'
sourcedf, destdf = load_timeseries(srcfile, destfile)

# %%
words = sourcedf.word.values
PlotChangePointsWords(words, sourcedf, destdf, use_savitzky_golay=False, marker='-')

# %% [markdown]
# Blue line shows: t compared to t - 4
# Red line shows:  t compared to t + 4

# %%
srcfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win4_src.csv'
destfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win4_dest.csv'
sourcedf, destdf = load_timeseries(srcfile, destfile)

# %%
words = sourcedf.word.values
PlotChangePointsWords(words, sourcedf, destdf, use_savitzky_golay=False, marker='-')

# %% [markdown]
# Blue line shows: t compared to t - 5
# Red line shows:  t compared to t + 5

# %%
srcfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win5_src.csv'
destfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_win5_dest.csv'
sourcedf, destdf = load_timeseries(srcfile, destfile)

# %%
words = sourcedf.word.values
PlotChangePointsWords(words, sourcedf, destdf, use_savitzky_golay=False, marker='-')

# %% [markdown]
# Polar comparison: Red represents compared to 1900 while Blue represents the same compared to 2005

# %%
srcfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_polar_src.csv'
destfile = '../skipgram/eng-fiction/output/changedwords/timeseries_changedwords_1000_polar_dest.csv'
sourcedf, destdf = load_timeseries(srcfile, destfile)

# %%
words = sourcedf.word.values
PlotChangePointsWords(words, sourcedf, destdf, use_savitzky_golay=True, marker='.', win_size=3)
